# %% [markdown]
# # Limpieza de datos
# ## Situacion Problema
# ### Santiago Chevez Trejo A01749887
# ### Jocelyn Ileana Balderas Sánchez A01798528
# ### Emiliano Alberto Celis Montero A01799348

# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('qs-world-rankings-2025_clean.csv')

# %%
# Contar las ocurrencias de cada país
conteo_paises = df["Location"].value_counts()

# Filtrar los países con un umbral mínimo de ocurrencias (por ejemplo, 10)
umbral = 5
paises_filtrados = conteo_paises[conteo_paises >= umbral]

# Crear la gráfica de pastel con los datos filtrados
paises_filtrados.plot.pie()
plt.title("Países con Mayor Presencia en el Ranking QS 2025")
plt.ylabel("")  # Opcional: para ocultar la etiqueta del eje y
plt.show()

# %%
# Calcular el promedio de "QS Overall Score" por "Location"
promedios = df.groupby('Location Full')["QS Overall Score"].sum()

# Ordenar los promedios de mayor a menor y seleccionar los 10 primeros
top_10_promedios = promedios.sort_values(ascending=False).head(10)

# Crear la gráfica de barras con los 10 mejores promedios
top_10_promedios.plot.bar()
plt.title("Top 10 Paises en QS Overall Score por Location")
plt.ylabel("QS Overall Score")
plt.xlabel("Location")
plt.show()

# %%
# Calcular el promedio de "QS Overall Score" por "Location"
promedios = df.groupby('Location Full')["Academic Reputation"].sum()

# Ordenar los promedios de mayor a menor y seleccionar los 10 primeros
top_10_promedios = promedios.sort_values(ascending=False).head(10)

# Crear la gráfica de barras con los 10 mejores promedios
top_10_promedios.plot.bar()
plt.title("Top 10 Paises de Academic Reputation Score por Location")
plt.ylabel("Suma Academic Reputation")
plt.xlabel("Location")
plt.show()

# %%
numerical_cols = ['2025 Rank','2024 Rank']
correlation_matrix_ranks = df[numerical_cols].corr()
correlation_matrix_ranks
# Out:
#            2025 Rank  2024 Rank
# 2025 Rank   1.000000   0.914314
# 2024 Rank   0.914314   1.000000

# %%
sns.heatmap(correlation_matrix_ranks, annot=True)
# Out:
# <Axes: >

# %%
numerical_cols = [
    "Academic Reputation",
    "Employer Reputation",
    "Faculty Student",
    "Citations per Faculty",
    "International Faculty",
    "International Students",
    "International Research Network",
    "Employment Outcomes",
    "Sustainability"]
correlation_matrix_others = df[numerical_cols].corr()
correlation_matrix_others
# Out:
#                                 Academic Reputation  Employer Reputation  \
# Academic Reputation                        1.000000             0.806420
# Employer Reputation                        0.806420             1.000000
# Faculty Student                            0.289099             0.298982
# Citations per Faculty                      0.119385             0.023124
# International Faculty                      0.091570             0.033551
# International Students                     0.196929             0.192849
# International Research Network             0.457033             0.182383
# Employment Outcomes                        0.636681             0.572252
# Sustainability                             0.485252             0.354428
#
#                                 Faculty Student  Citations per Faculty  \
# Academic Reputation                    0.289099               0.119385
# Employer Reputation                    0.298982               0.023124
# Faculty Student                        1.000000              -0.128794
# Citations per Faculty                 -0.128794               1.000000
# International Faculty                  0.060699               0.144461
# International Students                 0.171958               0.092284
# International Research Network        -0.085966               0.110553
# Employment Outcomes                    0.197488              -0.022853
# Sustainability                        -0.014309              -0.003627
#
#                                 International Faculty  International Students  \
# Academic Reputation                          0.091570                0.196929
# Employer Reputation                          0.033551                0.192849
# Faculty Student                              0.060699                0.171958
# Citations per Faculty                        0.144461                0.092284
# International Faculty                        1.000000                0.656938
# International Students                       0.656938                1.000000
# International Research Network               0.209099                0.189586
# Employment Outcomes                          0.142146                0.154545
# Sustainability                               0.312823                0.291450
#
#                                 International Research Network  \
# Academic Reputation                                   0.457033
# Employer Reputation                                   0.182383
# Faculty Student                                      -0.085966
# Citations per Faculty                                 0.110553
# International Faculty                                 0.209099
# International Students                                0.189586
# International Research Network                        1.000000
# Employment Outcomes                                   0.322333
# Sustainability                                        0.533316
#
#                                 Employment Outcomes  Sustainability
# Academic Reputation                        0.636681        0.485252
# Employer Reputation                        0.572252        0.354428
# Faculty Student                            0.197488       -0.014309
# Citations per Faculty                     -0.022853       -0.003627
# International Faculty                      0.142146        0.312823
# International Students                     0.154545        0.291450
# International Research Network             0.322333        0.533316
# Employment Outcomes                        1.000000        0.368446
# Sustainability                             0.368446        1.000000

# %%
sns.heatmap(correlation_matrix_others, annot=True)
# Out:
# <Axes: >
